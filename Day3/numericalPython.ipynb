# %% [markdown]
# # Solving some classic problems with numpy scipy
#
# ----
#
# By Adam A Miller (Northwestern/CIERA/SkAI)
# 15 Sept 2026

# %% [markdown]
# As a partial, but certainly not complete (!), example of the utility of `numpy` and `scipy`, this notebook includes some classic problems in physics and solves them numerically. There is also an introduction to random numbers and a brief discussion of monte carlo methods.

# %%
import numpy as np

# %% [markdown]
# ## Problem 1) The damped harmonic oscillator
#
# A damped harmonic oscillator can be described by three parameters: $m$ the mass of the oscillator, $k$ the spring constant, and $c$ the damping coefficient.
#
# The equation of motion for this system for this system is:
#
# $$mx'' + cx' + kx = 0$$
#
# We can solve this ordinary differential equation using scipy. If the initial conditions (i.e., the initial displacement and velocity) are known, then we can evolve the system in time to characterize its motion.

# %% [markdown]
# **Problem 1a**
#
# Write a function `damped_oscillator()` that will return the derivatives ($x'$ and $x''$) for the ODE at times t as a list $[dx/dt, dv/dt]$. The input for the function should be times `t` and a tuple `sv` that contains the state vector of the system (i.e., the position and velocity of the system). Assume that the three parameters $m, k, c$ are known.
#
# *Hint* – we must write the function in such a way that it can be solved as an initial value problem in `scipy` with [`solve_ivp`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.integrate.solve_ivp.html).

# %%
def damped_oscillator(t,sv): # complete
    x, v = sv # complete
    xdot = v # complete
    xdotdot = -(c*v + k*x)/m # complete
    return [xdot, xdotdot]

# %% [markdown]
# **Problem 1b**
#
# Use the initial conditions below to solve the initial value problem with `solve_ivp`.
#
# The inputs for `solve_ivp` are: `fun`: the function from above that will return the derivatives as a 1D array, `t_span`: a 2-tuple (t0, tf) giving the start and end times for the initial value problem, `sv0`: the initial displacement and velocity, and (optional argument) `t_eval` an array of times at which the solution will be reported.

# %%
from scipy.integrate import solve_ivp


m = 1.0                       # kg
f0 = 2.5                      # Hz (un-damped natural frequency in Hz)
omega0 = 2*np.pi*f0           # rad/s
k = m * omega0**2             # N/m
zeta = 0.10                   # damping ratio (underdamped if 0 < zeta < 1)
c = 2 * zeta * m * omega0     # N*s/m


# Initial conditions
sv0 = [1.0, 0.0]  # initial displacement and velocity
t_span = (0, 20)
t_eval = np.linspace(*t_span, 500)

sol = solve_ivp(damped_oscillator,t_span,sv0,t_eval=t_eval) # complete

# %% [markdown]
# **Problem 1c**
#
# Print the solution `sol` to determine its attributes. Did you successfully solve the ODE?

# %%
print(sol)
# Out:
#   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 1424
#      njev: 0
#       nlu: 0
#       sol: None
#    status: 0
#   success: True
#         t: array([ 0.        ,  0.04008016,  0.08016032,  0.12024048,  0.16032064,
#         0.2004008 ,  0.24048096,  0.28056112,  0.32064128,  0.36072144,
#         0.4008016 ,  0.44088176,  0.48096192,  0.52104208,  0.56112224,
#         0.6012024 ,  0.64128257,  0.68136273,  0.72144289,  0.76152305,
#         0.80160321,  0.84168337,  0.88176353,  0.92184369,  0.96192385,
#         1.00200401,  1.04208417,  1.08216433,  1.12224449,  1.16232465,
#         1.20240481,  1.24248497,  1.28256513,  1.32264529,  1.36272545,
#         1.40280561,  1.44288577,  1.48296593,  1.52304609,  1.56312625,
#         1.60320641,  1.64328657,  1.68336673,  1.72344689,  1.76352705,
#         1.80360721,  1.84368737,  1.88376754,  1.9238477 ,  1.96392786,
#         2.00400802,  2.04408818,  2.08416834,  2.1242485 ,  2.16432866,
#         2.20440882,  2.24448898,  2.28456914,  2.3246493 ,  2.36472946,
#         2.40480962,  2.44488978,  2.48496994,  2.5250501 ,  2.56513026,
#         2.60521042,  2.64529058,  2.68537074,  2.7254509 ,  2.76553106,
#         2.80561122,  2.84569138,  2.88577154,  2.9258517 ,  2.96593186,
#         3.00601202,  3.04609218,  3.08617234,  3.12625251,  3.16633267,
#         3.20641283,  3.24649299,  3.28657315,  3.32665331,  3.36673347,
#         3.40681363,  3.44689379,  3.48697395,  3.52705411,  3.56713427,
#         3.60721443,  3.64729459,  3.68737475,  3.72745491,  3.76753507,
#         3.80761523,  3.84769539,  3.88777555,  3.92785571,  3.96793587,
#         4.00801603,  4.04809619,  4.08817635,  4.12825651,  4.16833667,
#         4.20841683,  4.24849699,  4.28857715,  4.32865731,  4.36873747,
#         4.40881764,  4.4488978 ,  4.48897796,  4.52905812,  4.56913828,
#         4.60921844,  4.6492986 ,  4.68937876,  4.72945892,  4.76953908,
#         4.80961924,  4.8496994 ,  4.88977956,  4.92985972,  4.96993988,
#         5.01002004,  5.0501002 ,  5.09018036,  5.13026052,  5.17034068,
#         5.21042084,  5.250501  ,  5.29058116,  5.33066132,  5.37074148,
#         5.41082164,  5.4509018 ,  5.49098196,  5.53106212,  5.57114228,
#         5.61122244,  5.65130261,  5.69138277,  5.73146293,  5.77154309,
#         5.81162325,  5.85170341,  5.89178357,  5.93186373,  5.97194389,
#         6.01202405,  6.05210421,  6.09218437,  6.13226453,  6.17234469,
#         6.21242485,  6.25250501,  6.29258517,  6.33266533,  6.37274549,
#         6.41282565,  6.45290581,  6.49298597,  6.53306613,  6.57314629,
#         6.61322645,  6.65330661,  6.69338677,  6.73346693,  6.77354709,
#         6.81362725,  6.85370741,  6.89378758,  6.93386774,  6.9739479 ,
#         7.01402806,  7.05410822,  7.09418838,  7.13426854,  7.1743487 ,
#         7.21442886,  7.25450902,  7.29458918,  7.33466934,  7.3747495 ,
#         7.41482966,  7.45490982,  7.49498998,  7.53507014,  7.5751503 ,
#         7.61523046,  7.65531062,  7.69539078,  7.73547094,  7.7755511 ,
#         7.81563126,  7.85571142,  7.89579158,  7.93587174,  7.9759519 ,
#         8.01603206,  8.05611222,  8.09619238,  8.13627255,  8.17635271,
#         8.21643287,  8.25651303,  8.29659319,  8.33667335,  8.37675351,
#         8.41683367,  8.45691383,  8.49699399,  8.53707415,  8.57715431,
#         8.61723447,  8.65731463,  8.69739479,  8.73747495,  8.77755511,
#         8.81763527,  8.85771543,  8.89779559,  8.93787575,  8.97795591,
#         9.01803607,  9.05811623,  9.09819639,  9.13827655,  9.17835671,
#         9.21843687,  9.25851703,  9.29859719,  9.33867735,  9.37875752,
#         9.41883768,  9.45891784,  9.498998  ,  9.53907816,  9.57915832,
#         9.61923848,  9.65931864,  9.6993988 ,  9.73947896,  9.77955912,
#         9.81963928,  9.85971944,  9.8997996 ,  9.93987976,  9.97995992,
#        10.02004008, 10.06012024, 10.1002004 , 10.14028056, 10.18036072,
#        10.22044088, 10.26052104, 10.3006012 , 10.34068136, 10.38076152,
#        10.42084168, 10.46092184, 10.501002  , 10.54108216, 10.58116232,
#        10.62124248, 10.66132265, 10.70140281, 10.74148297, 10.78156313,
#        10.82164329, 10.86172345, 10.90180361, 10.94188377, 10.98196393,
#        11.02204409, 11.06212425, 11.10220441, 11.14228457, 11.18236473,
#        11.22244489, 11.26252505, 11.30260521, 11.34268537, 11.38276553,
#        11.42284569, 11.46292585, 11.50300601, 11.54308617, 11.58316633,
#        11.62324649, 11.66332665, 11.70340681, 11.74348697, 11.78356713,
#        11.82364729, 11.86372745, 11.90380762, 11.94388778, 11.98396794,
#        12.0240481 , 12.06412826, 12.10420842, 12.14428858, 12.18436874,
#        12.2244489 , 12.26452906, 12.30460922, 12.34468938, 12.38476954,
#        12.4248497 , 12.46492986, 12.50501002, 12.54509018, 12.58517034,
#        12.6252505 , 12.66533066, 12.70541082, 12.74549098, 12.78557114,
#        12.8256513 , 12.86573146, 12.90581162, 12.94589178, 12.98597194,
#        13.0260521 , 13.06613226, 13.10621242, 13.14629259, 13.18637275,
#        13.22645291, 13.26653307, 13.30661323, 13.34669339, 13.38677355,
#        13.42685371, 13.46693387, 13.50701403, 13.54709419, 13.58717435,
#        13.62725451, 13.66733467, 13.70741483, 13.74749499, 13.78757515,
#        13.82765531, 13.86773547, 13.90781563, 13.94789579, 13.98797595,
#        14.02805611, 14.06813627, 14.10821643, 14.14829659, 14.18837675,
#        14.22845691, 14.26853707, 14.30861723, 14.34869739, 14.38877756,
#        14.42885772, 14.46893788, 14.50901804, 14.5490982 , 14.58917836,
#        14.62925852, 14.66933868, 14.70941884, 14.749499  , 14.78957916,
#        14.82965932, 14.86973948, 14.90981964, 14.9498998 , 14.98997996,
#        15.03006012, 15.07014028, 15.11022044, 15.1503006 , 15.19038076,
#        15.23046092, 15.27054108, 15.31062124, 15.3507014 , 15.39078156,
#        15.43086172, 15.47094188, 15.51102204, 15.5511022 , 15.59118236,
#        15.63126253, 15.67134269, 15.71142285, 15.75150301, 15.79158317,
#        15.83166333, 15.87174349, 15.91182365, 15.95190381, 15.99198397,
#        16.03206413, 16.07214429, 16.11222445, 16.15230461, 16.19238477,
#        16.23246493, 16.27254509, 16.31262525, 16.35270541, 16.39278557,
#        16.43286573, 16.47294589, 16.51302605, 16.55310621, 16.59318637,
#        16.63326653, 16.67334669, 16.71342685, 16.75350701, 16.79358717,
#        16.83366733, 16.87374749, 16.91382766, 16.95390782, 16.99398798,
#        17.03406814, 17.0741483 , 17.11422846, 17.15430862, 17.19438878,
#        17.23446894, 17.2745491 , 17.31462926, 17.35470942, 17.39478958,
#        17.43486974, 17.4749499 , 17.51503006, 17.55511022, 17.59519038,
#        17.63527054, 17.6753507 , 17.71543086, 17.75551102, 17.79559118,
#        17.83567134, 17.8757515 , 17.91583166, 17.95591182, 17.99599198,
#        18.03607214, 18.0761523 , 18.11623246, 18.15631263, 18.19639279,
#        18.23647295, 18.27655311, 18.31663327, 18.35671343, 18.39679359,
#        18.43687375, 18.47695391, 18.51703407, 18.55711423, 18.59719439,
#        18.63727455, 18.67735471, 18.71743487, 18.75751503, 18.79759519,
#        18.83767535, 18.87775551, 18.91783567, 18.95791583, 18.99799599,
#        19.03807615, 19.07815631, 19.11823647, 19.15831663, 19.19839679,
#        19.23847695, 19.27855711, 19.31863727, 19.35871743, 19.3987976 ,
#        19.43887776, 19.47895792, 19.51903808, 19.55911824, 19.5991984 ,
#        19.63927856, 19.67935872, 19.71943888, 19.75951904, 19.7995992 ,
#        19.83967936, 19.87975952, 19.91983968, 19.95991984, 20.        ])
#  t_events: None
#         y: array([[ 1.00000000e+00,  8.16010742e-01,  3.59744799e-01,
#         -1.72438153e-01, -5.79035918e-01, -7.29126466e-01,
#         -5.98375217e-01, -2.67592509e-01,  1.20383769e-01,
#          4.19119434e-01,  5.31347942e-01,  4.38772738e-01,
#          1.99090090e-01, -8.40307073e-02, -3.03184104e-01,
#         -3.87270721e-01, -3.21638108e-01, -1.47974043e-01,
#          5.84384275e-02,  2.19374014e-01,  2.82147562e-01,
#          2.35832402e-01,  1.09992508e-01, -4.05845000e-02,
#         -1.58656023e-01, -2.05624900e-01, -1.72820046e-01,
#         -8.16904202e-02,  2.80936755e-02,  1.14755591e-01,
#          1.49772584e-01,  1.26704628e-01,  6.06662212e-02,
#         -1.93897453e-02, -8.29760844e-02, -1.09140040e-01,
#         -9.28207916e-02, -4.50260190e-02,  1.33470593e-02,
#          5.99906421e-02,  7.94786041e-02,  6.80456494e-02,
#          3.34078357e-02, -9.14171456e-03, -4.33699555e-02,
#         -5.79001630e-02, -4.98398839e-02, -2.47848629e-02,
#          6.23924677e-03,  3.13408602e-02,  4.21678359e-02,
#          3.65288309e-02,  1.83786641e-02, -4.23598567e-03,
#         -2.26480988e-02, -3.07181875e-02, -2.67482774e-02,
#         -1.36212630e-02,  2.86824790e-03,  1.63615637e-02,
#          2.23626978e-02,  1.95981276e-02,  1.00884577e-02,
#         -1.92311227e-03, -1.18244441e-02, -1.62835603e-02,
#         -1.43490510e-02, -7.47194278e-03,  1.28431256e-03,
#          8.53747213e-03,  1.18585372e-02,  1.05059210e-02,
#          5.53140009e-03, -8.49250984e-04, -6.16595659e-03,
#         -8.62998134e-03, -7.69533272e-03, -4.09305866e-03,
#          5.54144576e-04,  4.45367662e-03,  6.28301552e-03,
#          5.63192771e-03,  3.02858572e-03, -3.58563721e-04,
#         -3.21382878e-03, -4.57450313e-03, -4.12227814e-03,
#         -2.23984521e-03,  2.27695707e-04,  2.31992611e-03,
#          3.32823466e-03,  3.01846941e-03,  1.65577726e-03,
#         -1.40882351e-04, -1.67513036e-03, -2.42190819e-03,
#         -2.20856529e-03, -1.22421021e-03,  8.48158307e-05,
#          1.20806693e-03,  1.76295894e-03,  1.61614552e-03,
#          9.04808025e-04, -4.87631922e-05, -8.71403129e-04,
#         -1.28283242e-03, -1.18286605e-03, -6.68090641e-04,
#          2.60791546e-05,  6.28961670e-04,  9.33102960e-04,
#          8.65489251e-04,  4.93069914e-04, -1.23326355e-05,
#         -4.53868045e-04, -6.78750928e-04, -6.32844008e-04,
#         -3.63936076e-04,  4.03546487e-06,  3.27328286e-04,
#          4.93768909e-04,  4.62806840e-04,  2.68630394e-04,
#          6.46776833e-07, -2.35861214e-04, -3.59268717e-04,
#         -3.38438726e-04, -1.98264865e-04, -3.07534366e-06,
#          1.69938423e-04,  2.61398137e-04,  2.47515193e-04,
#          1.46233871e-04,  4.12428389e-06, -1.22490452e-04,
#         -1.90130566e-04, -1.80960877e-04, -1.07793292e-04,
#         -4.33244993e-06,  8.83040066e-05,  1.38279572e-04,
#          1.32261626e-04,  7.94254068e-05,  4.10698852e-06,
#         -6.36629175e-05, -1.00552249e-04, -9.66519536e-05,
#         -5.84960788e-05, -3.68325745e-06,  4.59055176e-05,
#          7.31004640e-05,  7.06359763e-05,  4.30464958e-05,
#          3.17952247e-06, -3.31227535e-05, -5.31184764e-05,
#         -5.16454261e-05, -3.16472231e-05, -2.65840540e-06,
#          2.39054861e-05,  3.86340315e-05,  3.77141372e-05,
#          2.32550284e-05,  2.14265462e-06, -1.72261026e-05,
#         -2.81980672e-05, -2.75255203e-05, -1.70433988e-05,
#         -1.64679412e-06,  1.25408532e-05,  2.04764827e-05,
#          2.00848062e-05,  1.24905747e-05,  1.26266736e-06,
#         -9.06218126e-06, -1.49080114e-05, -1.46884790e-05,
#         -9.12045790e-06, -9.71078141e-07,  6.58736948e-06,
#          1.08973022e-05,  1.06843667e-05,  6.67505453e-06,
#          7.13068157e-07, -4.84592445e-06, -7.96960998e-06,
#         -7.78682764e-06, -4.85395801e-06, -4.81458777e-07,
#          3.55693098e-06,  5.82242936e-06,  5.67789454e-06,
#          3.53762793e-06,  3.24292903e-07, -2.62394602e-06,
#         -4.26634494e-06, -4.14173167e-06, -2.56823870e-06,
#         -2.10502742e-07,  1.94933395e-06,  3.14455887e-06,
#          3.02567339e-06,  1.84885673e-06,  1.29737847e-07,
#         -1.46966323e-06, -2.33500000e-06, -2.23413715e-06,
#         -1.31192987e-06, -5.56140188e-08,  1.11767925e-06,
#          1.78804807e-06,  1.68588925e-06,  9.77482200e-07,
#         -6.79885963e-08, -9.43978392e-07, -1.38063447e-06,
#         -1.23902467e-06, -6.60143894e-07,  8.30638786e-08,
#          7.41774764e-07,  1.04997119e-06,  9.44641742e-07,
#          4.80422769e-07, -1.32744117e-07, -6.16368689e-07,
#         -8.29866581e-07, -7.00252715e-07, -3.16241404e-07,
#          1.35811519e-07,  5.09740988e-07,  6.65493647e-07,
#          5.46446097e-07,  2.41434363e-07, -1.56928143e-07,
#         -4.48203365e-07, -5.55947215e-07, -4.37068509e-07,
#         -1.36446279e-07,  1.81340023e-07,  4.20497494e-07,
#          5.10508517e-07,  4.13543708e-07,  1.36996024e-07,
#         -2.19622144e-07, -4.78002399e-07, -5.56294600e-07,
#         -4.16699579e-07, -9.93263495e-08,  2.23140315e-07,
#          4.71850202e-07,  5.54002910e-07,  3.76071126e-07,
#          7.93848646e-08, -2.48628234e-07, -4.96074639e-07,
#         -5.03442283e-07, -3.33396753e-07, -3.07616482e-08,
#          2.95801775e-07,  4.58719506e-07,  4.53411494e-07,
#          2.59963771e-07, -4.78277911e-08, -3.00668109e-07,
#         -4.45107939e-07, -4.13996254e-07, -2.07848214e-07,
#          8.36080218e-08,  3.33284311e-07,  4.45993274e-07,
#          3.79105875e-07,  1.60700613e-07, -1.01306631e-07,
#         -3.10242808e-07, -4.04473644e-07, -3.30929328e-07,
#         -1.41425554e-07,  8.27256147e-08,  3.08435217e-07,
#          4.32350177e-07,  3.35634171e-07,  1.34896508e-07,
#         -1.30242791e-07, -3.63389284e-07, -4.11648202e-07,
#         -3.18106104e-07, -9.29270643e-08,  1.88506701e-07,
#          3.59975132e-07,  4.00911823e-07,  2.80808298e-07,
#          2.84706930e-08, -2.20093137e-07, -3.87797584e-07,
#         -4.21942716e-07, -2.81296106e-07, -9.77124715e-09,
#          2.71459449e-07,  4.58190728e-07,  4.63915525e-07,
#          2.77898918e-07, -1.96960670e-08, -2.96915235e-07,
#         -4.56088703e-07, -4.42955367e-07, -2.50522340e-07,
#          4.69756010e-08,  3.05089371e-07,  4.51685620e-07,
#          4.23489972e-07,  2.10471825e-07, -5.19477263e-08,
#         -3.06884955e-07, -4.54908228e-07, -3.84404500e-07,
#         -1.92426540e-07,  8.42747535e-08,  3.44471038e-07,
#          4.26026439e-07,  3.59019248e-07,  1.42626607e-07,
#         -1.47222288e-07, -3.43006965e-07, -4.16060211e-07,
#         -3.21181576e-07, -7.98265671e-08,  1.82500646e-07,
#          3.85675465e-07,  4.70607980e-07,  3.80795139e-07,
#          1.26325840e-07, -2.16189609e-07, -5.15748742e-07,
#         -6.28496712e-07, -4.91643174e-07, -1.46531255e-07,
#          2.65586408e-07,  5.77013998e-07,  6.77052503e-07,
#          5.22023268e-07,  1.35899646e-07, -3.13885093e-07,
#         -6.20831945e-07, -6.87019285e-07, -4.71745202e-07,
#         -8.91219193e-08,  2.98663034e-07,  5.88169102e-07,
#          6.29088351e-07,  4.03118196e-07,  4.94553929e-08,
#         -3.36012723e-07, -5.52834690e-07, -5.40610461e-07,
#         -3.21690814e-07,  3.64968885e-08,  3.37917470e-07,
#          4.99005680e-07,  4.57731058e-07,  2.23159396e-07,
#         -8.40933403e-08, -3.38948772e-07, -4.60119608e-07,
#         -4.04440662e-07, -1.80644993e-07,  1.05050028e-07,
#          3.37387180e-07,  4.54603778e-07,  3.93837851e-07,
#          1.58020207e-07, -1.07244879e-07, -3.52194426e-07,
#         -4.80226543e-07, -3.72716827e-07, -1.44512509e-07,
#          1.45082885e-07,  3.95894589e-07,  4.48393374e-07,
#          3.42597543e-07,  9.77721009e-08, -2.02488019e-07,
#         -3.83472539e-07, -4.23762971e-07, -2.91570940e-07,
#         -2.55107638e-08,  2.28785910e-07,  4.01781954e-07,
#          4.30609506e-07,  2.82832573e-07,  6.46232385e-09,
#         -2.79925369e-07, -4.61324287e-07, -4.56883717e-07,
#         -2.66270330e-07,  2.53883631e-08,  2.87678301e-07,
#          4.35892719e-07,  4.20253560e-07,  2.24850706e-07,
#         -2.78977489e-08, -2.69234261e-07, -4.49076770e-07,
#         -4.64995366e-07, -2.38515889e-07,  5.15046986e-08,
#          3.33187379e-07,  4.97023796e-07,  4.22714450e-07,
#          2.12424930e-07, -8.97363330e-08, -3.68140656e-07,
#         -4.55861719e-07, -3.84251166e-07, -1.50306273e-07,
#          1.54054608e-07,  3.58555137e-07,  4.36080627e-07,
#          3.34046004e-07,  8.37352592e-08, -1.85976221e-07,
#         -4.05245210e-07, -5.12276951e-07, -4.54035106e-07,
#         -2.17073888e-07,  1.72461942e-07,  5.92992456e-07,
#          8.33541176e-07,  7.83548686e-07,  4.25410707e-07,
#         -1.65595846e-07, -7.68791297e-07, -1.09908957e-06,
#         -1.02094539e-06, -5.32993779e-07,  2.21714189e-07,
#          8.85114993e-07,  1.20468594e-06,  1.06835481e-06,
#          4.77990092e-07, -2.84974587e-07, -8.91968941e-07,
#         -1.15331926e-06, -9.21161502e-07, -3.58961148e-07,
#          3.04504551e-07,  8.34168391e-07,  9.61543244e-07,
#          7.31169513e-07,  2.13816760e-07, -3.33372075e-07,
#         -6.96099157e-07, -7.64227613e-07, -5.20984228e-07,
#         -1.07519773e-07,  2.99413320e-07,  5.69610381e-07,
#          6.00909122e-07,  4.01168114e-07,  7.20251773e-08,
#         -2.83337130e-07, -4.85939334e-07, -5.04174793e-07,
#         -3.18038280e-07,  3.62437935e-09,  2.84565130e-07,
#          4.55682495e-07,  4.46699154e-07,  2.53025345e-07,
#         -4.29071384e-08, -3.09959792e-07, -4.47489944e-07,
#         -4.07900392e-07, -2.02541994e-07,  6.19509886e-08,
#          2.89378357e-07,  4.13421687e-07,  3.60857894e-07,
#          1.80442516e-07, -5.42595137e-08, -2.98151378e-07,
#         -4.29264836e-07, -3.51840557e-07, -1.65030327e-07,
#          1.04960505e-07,  3.42559752e-07,  4.05041695e-07,
#          3.31836241e-07,  1.13043150e-07, -1.64563975e-07,
#         -3.42657030e-07, -4.05843793e-07, -3.02650517e-07,
#         -5.94934436e-08,  1.98561635e-07,  4.04301034e-07,
#          4.93932838e-07,  4.05222563e-07,  1.41962571e-07,
#         -2.26027928e-07, -5.25023303e-07],
#        [ 0.00000000e+00, -8.69042443e+00, -1.32243805e+01,
#         -1.24521356e+01, -7.28170800e+00, -1.02314714e-01,
#          6.26461440e+00,  9.61630573e+00,  9.10863392e+00,
#          5.37766456e+00,  1.49776131e-01, -4.51116612e+00,
#         -6.99639311e+00, -6.66354969e+00, -3.96886096e+00,
#         -1.63309552e-01,  3.24990849e+00,  5.08650051e+00,
#          4.87412976e+00,  2.92938721e+00,  1.59520749e-01,
#         -2.33944130e+00, -3.70015509e+00, -3.56475902e+00,
#         -2.16140131e+00, -1.44868645e-01,  1.68428855e+00,
#          2.68957903e+00,  2.60727958e+00,  1.59442587e+00,
#          1.27353799e-01, -1.21201666e+00, -1.95613916e+00,
#         -1.90636507e+00, -1.17610354e+00, -1.07915657e-01,
#          8.71978943e-01,  1.42166974e+00,  1.39419793e+00,
#          8.67119984e-01,  9.03222635e-02, -6.27282648e-01,
#         -1.03372086e+00, -1.01914288e+00, -6.39429322e-01,
#         -7.38996022e-02,  4.50941348e-01,  7.51165238e-01,
#          7.45305462e-01,  4.71339026e-01,  6.01014956e-02,
#         -3.24166951e-01, -5.46111497e-01, -5.44748277e-01,
#         -3.47426134e-01, -4.80696295e-02,  2.32938818e-01,
#          3.96768278e-01,  3.98327234e-01,  2.55874365e-01,
#          3.82785376e-02, -1.67451831e-01, -2.88322351e-01,
#         -2.91015854e-01, -1.88531055e-01, -3.01814593e-02,
#          1.20218867e-01,  2.09525502e-01,  2.12676444e-01,
#          1.38826112e-01,  2.36744743e-02, -8.63342322e-02,
#         -1.52180292e-01, -1.55453482e-01, -1.02202894e-01,
#         -1.85021797e-02,  6.19930403e-02,  1.10565937e-01,
#          1.13536845e-01,  7.52704769e-02,  1.43623165e-02,
#         -4.44662956e-02, -8.03203538e-02, -8.29594181e-02,
#         -5.53868791e-02, -1.11164913e-02,  3.19037486e-02,
#          5.83231131e-02,  6.06188310e-02,  4.07527643e-02,
#          8.58171993e-03, -2.28906913e-02, -4.23567589e-02,
#         -4.42654403e-02, -2.99938113e-02, -6.59382683e-03,
#          1.63995705e-02,  3.07653117e-02,  3.23313504e-02,
#          2.20669304e-02,  5.05615120e-03, -1.17511196e-02,
#         -2.23330665e-02, -2.36218276e-02, -1.62273057e-02,
#         -3.87145429e-03,  8.42537592e-03,  1.62131262e-02,
#          1.72462800e-02,  1.19320115e-02,  2.94885316e-03,
#         -6.03802950e-03, -1.17710078e-02, -1.25892250e-02,
#         -8.77036806e-03, -2.23945038e-03,  4.32237971e-03,
#          8.54654418e-03,  9.18888773e-03,  6.44820231e-03,
#          1.70013132e-03, -3.09252207e-03, -6.20434839e-03,
#         -6.70871464e-03, -4.73824326e-03, -1.28911732e-03,
#          2.21183747e-03,  4.50254893e-03,  4.89877612e-03,
#          3.48008560e-03,  9.76853462e-04, -1.58241095e-03,
#         -3.26755739e-03, -3.57552976e-03, -2.55612712e-03,
#         -7.37918651e-04,  1.13202264e-03,  2.37147927e-03,
#          2.60905382e-03,  1.87668856e-03,  5.55824655e-04,
#         -8.09530865e-04, -1.72124525e-03, -1.90344702e-03,
#         -1.37764680e-03, -4.17760055e-04,  5.78809631e-04,
#          1.24929043e-03,  1.38840518e-03,  1.01136510e-03,
#          3.13452336e-04, -4.13957212e-04, -9.06643771e-04,
#         -1.01254788e-03, -7.42313984e-04, -2.34869425e-04,
#          2.96294428e-04,  6.57664468e-04,  7.38800375e-04,
#          5.44070421e-04,  1.75716205e-04, -2.12562187e-04,
#         -4.77201392e-04, -5.39159936e-04, -3.98180459e-04,
#         -1.31108264e-04,  1.52812020e-04,  3.47873431e-04,
#          3.93075307e-04,  2.91038584e-04,  9.62357924e-05,
#         -1.10611022e-04, -2.52529840e-04, -2.86514572e-04,
#         -2.13080746e-04, -7.10019412e-05,  7.95734954e-05,
#          1.83656748e-04,  2.09398165e-04,  1.55248185e-04,
#          5.23040942e-05, -5.80008574e-05, -1.34534736e-04,
#         -1.53045259e-04, -1.12999653e-04, -3.76767539e-05,
#          4.29281142e-05,  9.85136385e-05,  1.11393931e-04,
#          8.24082522e-05,  2.73430313e-05, -3.16531582e-05,
#         -7.22106846e-05, -8.12911064e-05, -5.99943538e-05,
#         -1.96309710e-05,  2.35856838e-05,  5.31350449e-05,
#          5.95250328e-05,  4.35176256e-05,  1.39134149e-05,
#         -1.78404180e-05, -3.93060568e-05, -4.39252029e-05,
#         -3.14483333e-05, -9.47368603e-06,  1.36237001e-05,
#          2.92120430e-05,  3.30864336e-05,  2.38459150e-05,
#          5.67854029e-06, -1.18667036e-05, -2.31618178e-05,
#         -2.45405106e-05, -1.67930172e-05, -3.89514866e-06,
#          9.66315068e-06,  1.79258029e-05,  1.88696408e-05,
#          1.22288930e-05,  1.69716198e-06, -8.07531059e-06,
#         -1.38761753e-05, -1.38693622e-05, -9.01137148e-06,
#         -1.25079765e-06,  6.93025116e-06,  1.13721882e-05,
#          1.12775963e-05,  6.64359151e-06, -3.95150036e-07,
#         -6.25749868e-06, -9.29770907e-06, -8.45748565e-06,
#         -4.47147144e-06,  5.55504974e-07,  5.17487742e-06,
#          7.79916099e-06,  7.10388167e-06,  4.80622755e-06,
#          2.63935850e-07, -5.54219098e-06, -9.23048017e-06,
#         -8.36068474e-06, -4.83736878e-06,  1.14080758e-06,
#          6.99937248e-06,  9.15721335e-06,  8.27440065e-06,
#          3.80698288e-06, -2.63196673e-06, -7.27014216e-06,
#         -9.04452257e-06, -7.11417992e-06, -2.13830475e-06,
#          3.18378718e-06,  6.91805640e-06,  7.76661354e-06,
#          5.47807854e-06,  1.20807103e-06, -3.05796742e-06,
#         -6.07710379e-06, -6.76610387e-06, -4.59130540e-06,
#         -1.34444799e-06,  2.71674212e-06,  6.38221188e-06,
#          7.05731274e-06,  4.73145143e-06,  7.77700748e-07,
#         -3.84669204e-06, -6.64474560e-06, -6.58626093e-06,
#         -4.15067862e-06,  2.57705318e-07,  4.38939619e-06,
#          6.53342784e-06,  6.40519515e-06,  3.46231891e-06,
#         -1.12060713e-06, -4.89790987e-06, -6.81268348e-06,
#         -5.93178289e-06, -2.57343216e-06,  1.57082127e-06,
#          4.85781804e-06,  6.17460100e-06,  5.06236732e-06,
#          1.88843567e-06, -1.63534637e-06, -4.53334239e-06,
#         -5.90861380e-06, -4.65955964e-06, -2.10995434e-06,
#          1.13532752e-06,  4.81903917e-06,  7.22608198e-06,
#          5.75422914e-06,  2.40020790e-06, -2.03880000e-06,
#         -6.29233335e-06, -7.59124103e-06, -5.94165113e-06,
#         -2.21516083e-06,  3.02539733e-06,  7.18156318e-06,
#          7.73916850e-06,  5.71753295e-06,  1.08502956e-06,
#         -4.17193316e-06, -7.04615215e-06, -7.41277802e-06,
#         -4.64091526e-06,  1.81296165e-07,  4.41255418e-06,
#          6.83394704e-06,  6.45160064e-06,  3.42339745e-06,
#         -7.48309572e-07, -4.31393727e-06, -6.13475051e-06,
#         -5.57654337e-06, -2.69520962e-06,  7.67996417e-07,
#          4.02014111e-06,  6.06301415e-06,  5.35625166e-06,
#          3.47168884e-06,  5.03722939e-07, -3.97724798e-06,
#         -8.24420956e-06, -8.44261844e-06, -5.08229133e-06,
#         -9.47509816e-08,  6.00422987e-06,  1.03722306e-05,
#          9.44145129e-06,  5.96064929e-06, -4.04204329e-07,
#         -7.92531305e-06, -1.18270232e-05, -1.03179933e-05,
#         -5.18380444e-06,  2.54877046e-06,  8.89557657e-06,
#          1.10818166e-05,  9.16630706e-06,  3.20067226e-06,
#         -3.83048299e-06, -8.53757845e-06, -9.78334823e-06,
#         -6.95750560e-06, -1.60100535e-06,  3.75442369e-06,
#          7.33890763e-06,  7.98174466e-06,  5.35825149e-06,
#          1.26963209e-06, -3.30012915e-06, -6.90044610e-06,
#         -7.22434609e-06, -5.14847973e-06, -1.07232016e-06,
#          4.03732062e-06,  7.28631990e-06,  7.39172145e-06,
#          4.94628536e-06,  3.97104254e-08, -5.06311279e-06,
#         -7.50190799e-06, -7.42199104e-06, -4.13054580e-06,
#          1.14136417e-06,  5.43251621e-06,  7.57160568e-06,
#          6.60418173e-06,  2.86470454e-06, -1.69597830e-06,
#         -5.28718233e-06, -6.69593166e-06, -5.44456577e-06,
#         -2.03488870e-06,  1.73207449e-06,  4.82626150e-06,
#          6.23783373e-06,  4.85906199e-06,  2.30821682e-06,
#         -1.18410208e-06, -5.15743275e-06, -7.55981390e-06,
#         -5.87444553e-06, -2.35920941e-06,  2.32045402e-06,
#          6.51346283e-06,  7.40714934e-06,  5.77712097e-06,
#          1.79374584e-06, -3.39817826e-06, -6.74357590e-06,
#         -7.75344334e-06, -5.93319426e-06, -1.14327477e-06,
#          4.50266029e-06,  7.71437726e-06,  8.16665132e-06,
#          5.17157337e-06, -8.23292322e-08, -4.71574139e-06,
#         -7.36840060e-06, -6.97862746e-06, -3.75062602e-06,
#          6.80256687e-07,  4.48289318e-06,  6.47537406e-06,
#          5.93424031e-06,  2.97351834e-06, -6.10631406e-07,
#         -4.15978651e-06, -6.44761801e-06, -5.78626715e-06,
#         -4.70643620e-06, -1.84465364e-06,  3.62540732e-06,
#          9.66792697e-06,  1.13849391e-05,  8.48856592e-06,
#          3.61528646e-06, -4.67154419e-06, -1.36764829e-05,
#         -1.65578299e-05, -1.22107525e-05, -4.32560908e-06,
#          7.27438866e-06,  1.78642899e-05,  1.90478926e-05,
#          1.37561181e-05,  2.81121875e-06, -1.09013173e-05,
#         -1.92494376e-05, -1.89648345e-05, -1.16053624e-05,
#          9.71085795e-07,  1.19421475e-05,  1.71335653e-05,
#          1.52904889e-05,  7.30003409e-06, -2.36673591e-06,
#         -1.01402974e-05, -1.34388799e-05, -1.12646871e-05,
#         -5.44535606e-06,  2.09583491e-06,  8.74743339e-06,
#          1.10362260e-05,  9.19740120e-06,  3.65472793e-06,
#         -2.99919139e-06, -7.58983563e-06, -8.98699008e-06,
#         -6.67236049e-06, -2.06923353e-06,  2.70938733e-06,
#          6.26248904e-06,  7.36917033e-06,  5.39301283e-06,
#          2.06712020e-06, -2.32020375e-06, -6.42694976e-06,
#         -7.43143747e-06, -5.42361577e-06, -1.44694444e-06,
#          3.48207199e-06,  6.62677765e-06,  6.98421138e-06,
#          4.72511182e-06,  2.70389340e-07, -4.03638374e-06,
#         -6.49164979e-06, -6.53334112e-06, -3.76266320e-06,
#          6.03565867e-07,  4.38594314e-06,  6.41753021e-06,
#          5.83332186e-06,  2.89233833e-06, -1.00380493e-06,
#         -4.24023531e-06, -5.84965332e-06, -5.20328589e-06,
#         -2.36129495e-06,  9.15392626e-07,  4.05967733e-06,
#          6.05083927e-06,  5.23553869e-06,  3.54883384e-06,
#          7.40866074e-07, -3.91413778e-06, -8.74032962e-06,
#         -9.66024007e-06, -4.86230430e-06]])
#  y_events: None

# %% [markdown]
# **Problem 1d**
#
# Plot the numerical solution for the position as a function of time.
#
# Does the plot correspond with your expectation? Why or why not?
#
# *Note* – feel free to skip this, especially if you are not familiar with `matplotlib`.

# %%
import matplotlib.pyplot as plt

plt.plot(sol.t,sol.y[0])
plt.show()

# complete
# complete
# complete

# %% [markdown]
# ## Problem 2) Random number generation
#
# `numpy` has several built in modules to generate (psuedo) random numbers. These are extremely useful for different types of [monte carlo]() tests, where random numbers are drawn to assess different types of probabistic outcomes.

# %% [markdown]
# **Problem 2a**
#
# `numpy` can generate a random number over the interval $[0, 1)$ using the [`numpy.random.rand`](https://numpy.org/doc/stable/reference/random/generated/numpy.random.rand.html) method. The argument to this function is the dimensions of the array that you would like to be returned.
#
#
#
# Generate a single number between 0 and 1.

# %%
print(f'The random number is {np.random.rand(1)}') # complete
# Out:
# The random number is [0.33539995]

# %% [markdown]
# **Problem 2b**
#
# Generate 100 random numbers. What is the minimum, maximum, and mean of the numbers that have been drawn?

# %%
rns = np.random.rand(100) # complete

print(f'''The minimum is {np.min(rns):.3f}, 
the maximum is {np.max(rns):.3f}, 
and the mean is {np.mean(rns):.3f}''')
# Out:
# The minimum is 0.039,
# the maximum is 0.991,
# and the mean is 0.555

# %% [markdown]
# **Problem 2c**
#
# If you instead generate 10,000 random numbers, do you get answers for the min, max, and mean that are closer to your expectations?

# %%
rns = np.random.rand(10_000) # complete

print(f'''The minimum is {np.min(rns):.3f}, 
the maximum is {np.max(rns):.3f}, 
and the mean is {np.mean(rns):.3f}''')
# Out:
# The minimum is 0.000,
# the maximum is 1.000,
# and the mean is 0.504

# %% [markdown]
# **Problem 2d**
#
# Using [`numpy.random.Generator.normal`](https://numpy.org/doc/stable/reference/random/generated/numpy.random.normal.html) generate 500 random numbers from a Gaussian distribution with a mean of $1851$ and a standard deviation of 6.
#
# What is the mean and the standard deviation for the randomly generated numbers? Are the answers consistent with your expectations? (what if you change the number of samples?)
#
# *Hint* – be sure that you calculate the *sample* standard deviation.

# %%
rng = np.random.normal(1851,6,500)# complete

print(f'''The mean is {np.mean(rng):.3f} and the standard deviation is {np.std(rng):.3f}''')
# Out:
# The mean is 1850.851 and the standard deviation is 6.111

# %% [markdown]
# ## Problem 3) A random walk
#
# Many physical phenomena can be described via a random walk (essentially any process with a moderately high cross section in a moderate to high density medium). In this problem we will simulate a 2D random walk as a proxy for understanding diffusion.

# %% [markdown]
# **Problem 3a**
#
# To simulate a random walk, draw a random number for a 2D Gaussian distibution where the mean along both axes is 0 and the standard deviation along both axes is 1. (You may assume there is no covariance between the two axes)
#
# *Hint* – if you don't want to use `numpy.random.normal` you can use the [`numpy.Generator.random.multivariate_normal`](https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.multivariate_normal.html#numpy.random.Generator.multivariate_normal) method.

# %%
rng = np.random.multivariate_normal([0,0],[[1,0],[0,1]],1) # complete

# complete
# complete
# complete


print(rng) # complete
# Out:
# [[-0.23282116  0.2900529 ]]

# %% [markdown]
# **Problem 3b**
#
# Create a walker that 100 steps. What is the final position of the walker?
#
# Has it moved more or less than you expected?

# %%
nsteps = 100 # complete

class Walker():
    def __init__(self, steps):
        self.steps = steps
        self.position = np.array([0,0])
    def walk(self):
        rng = np.random.multivariate_normal([0,0],[[1,0],[0,1]],self.steps)
        self.position = sum(rng)
        return self.position
            
walker100 = Walker(nsteps)

print(f'The walker has moved to {walker100.walk()}')  # complete
# Out:
# The walker has moved to [-6.53823061 -8.89146728]

# %% [markdown]
# **Problem 3c**
#
# Simulate 1000 different walkers that each proceed for 10 steps.
#
# Plot the final position of each walker after 10 steps. Calculate the average position of each walker after 10 steps. Calculate the average distance from the origin of each walker.

# %%
walkers = []

for i in range(1000):
    walker = Walker(10)
    walkers.append(walker.walk())
    
walkersnp = np.array(walkers)

# %%
fig, ax = plt.subplots()
plt.scatter(walkersnp[:,0],walkersnp[:,1]) # complete

# %% [markdown]
# **Problem 3d**
#
# Repeat this problem for 1000 walkers and 100 steps. Same thing for 1000 steps. Make a single plot showing the results for all three of these runs.
#
# Do the results make sense?

# %%
walkers10 = []

for i in range(1000):
    walker = Walker(10)
    walkers10.append(walker.walk())
    
walkersnp_10 = np.array(walkers10)


walkers100 = []

for i in range(1000):
    walker = Walker(100)
    walkers100.append(walker.walk())
    
walkersnp_100 = np.array(walkers100)


walkers1000 = []

for i in range(1000):
    walker = Walker(1000)
    walkers1000.append(walker.walk())
    
walkersnp_1000 = np.array(walkers1000)

# %%
# complete

# complete
# complete

# %%
fig, ax = plt.subplots()

# complete

# complete
# complete

fig.legend(loc=1)
